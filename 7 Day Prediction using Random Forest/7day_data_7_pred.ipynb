# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import csv
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
FilePath = '/content/drive/MyDrive/ML-Project/weekly_final.csv'
# use dataset maker with numdays = 14

# %%
DF = pd.read_csv(FilePath,delimiter=',')

columns = list(DF.columns)

for i in range(len(columns)):
  if "1_" in columns[i]:columns[i] = columns[i][2:]

DF.columns = columns
DF.drop(columns=['Unnamed: 0'],inplace=True)
print(columns)

DF.head()
# Out:
# ['Unnamed: 0', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am', 'Temp3pm', 'RainToday', 'Year', 'Month', 'Day', '2_Location', '2_MinTemp', '2_MaxTemp', '2_Rainfall', '2_Evaporation', '2_Sunshine', '2_WindGustDir', '2_WindGustSpeed', '2_WindDir9am', '2_WindDir3pm', '2_WindSpeed9am', '2_WindSpeed3pm', '2_Humidity9am', '2_Humidity3pm', '2_Pressure9am', '2_Pressure3pm', '2_Cloud9am', '2_Cloud3pm', '2_Temp9am', '2_Temp3pm', '2_RainToday', '2_Year', '2_Month', '2_Day', '3_Location', '3_MinTemp', '3_MaxTemp', '3_Rainfall', '3_Evaporation', '3_Sunshine', '3_WindGustDir', '3_WindGustSpeed', '3_WindDir9am', '3_WindDir3pm', '3_WindSpeed9am', '3_WindSpeed3pm', '3_Humidity9am', '3_Humidity3pm', '3_Pressure9am', '3_Pressure3pm', '3_Cloud9am', '3_Cloud3pm', '3_Temp9am', '3_Temp3pm', '3_RainToday', '3_Year', '3_Month', '3_Day', '4_Location', '4_MinTemp', '4_MaxTemp', '4_Rainfall', '4_Evaporation', '4_Sunshine', '4_WindGustDir', '4_WindGustSpeed', '4_WindDir9am', '4_WindDir3pm', '4_WindSpeed9am', '4_WindSpeed3pm', '4_Humidity9am', '4_Humidity3pm', '4_Pressure9am', '4_Pressure3pm', '4_Cloud9am', '4_Cloud3pm', '4_Temp9am', '4_Temp3pm', '4_RainToday', '4_Year', '4_Month', '4_Day', '5_Location', '5_MinTemp', '5_MaxTemp', '5_Rainfall', '5_Evaporation', '5_Sunshine', '5_WindGustDir', '5_WindGustSpeed', '5_WindDir9am', '5_WindDir3pm', '5_WindSpeed9am', '5_WindSpeed3pm', '5_Humidity9am', '5_Humidity3pm', '5_Pressure9am', '5_Pressure3pm', '5_Cloud9am', '5_Cloud3pm', '5_Temp9am', '5_Temp3pm', '5_RainToday', '5_Year', '5_Month', '5_Day', '6_Location', '6_MinTemp', '6_MaxTemp', '6_Rainfall', '6_Evaporation', '6_Sunshine', '6_WindGustDir', '6_WindGustSpeed', '6_WindDir9am', '6_WindDir3pm', '6_WindSpeed9am', '6_WindSpeed3pm', '6_Humidity9am', '6_Humidity3pm', '6_Pressure9am', '6_Pressure3pm', '6_Cloud9am', '6_Cloud3pm', '6_Temp9am', '6_Temp3pm', '6_RainToday', '6_Year', '6_Month', '6_Day', '7_Location', '7_MinTemp', '7_MaxTemp', '7_Rainfall', '7_Evaporation', '7_Sunshine', '7_WindGustDir', '7_WindGustSpeed', '7_WindDir9am', '7_WindDir3pm', '7_WindSpeed9am', '7_WindSpeed3pm', '7_Humidity9am', '7_Humidity3pm', '7_Pressure9am', '7_Pressure3pm', '7_Cloud9am', '7_Cloud3pm', '7_Temp9am', '7_Temp3pm', '7_RainToday', '7_Year', '7_Month', '7_Day', 'rainafter1days', 'rainafter2days', 'rainafter3days', 'rainafter4days', 'rainafter5days', 'rainafter6days', 'rainafter7days']
#    Location  MinTemp  MaxTemp  ...  rainafter5days  rainafter6days  rainafter7days
# 0  Canberra      8.0     24.3  ...              No              No              No
# 1  Canberra     14.0     26.9  ...              No              No              No
# 2  Canberra     13.7     23.4  ...              No              No              No
# 3  Canberra     13.3     15.5  ...              No              No              No
# 4  Canberra      7.6     16.1  ...              No              No             Yes
#
# [5 rows x 175 columns]

# %%
DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127433 entries, 0 to 127432
# Columns: 175 entries, Location to rainafter7days
# dtypes: float64(112), int64(21), object(42)
# memory usage: 170.1+ MB

# %%
columns = DF.columns

for c in columns:
  print('null count in',c,'=',DF[c].isnull().sum())
# Out:
# null count in Location = 0
# null count in MinTemp = 484
# null count in MaxTemp = 267
# null count in Rainfall = 617
# null count in Evaporation = 51815
# null count in Sunshine = 58741
# null count in WindGustDir = 8307
# null count in WindGustSpeed = 8282
# null count in WindDir9am = 8651
# null count in WindDir3pm = 3076
# null count in WindSpeed9am = 994
# null count in WindSpeed3pm = 2068
# null count in Humidity9am = 1409
# null count in Humidity3pm = 2951
# null count in Pressure9am = 12120
# null count in Pressure3pm = 12088
# null count in Cloud9am = 45753
# null count in Cloud3pm = 48672
# null count in Temp9am = 613
# null count in Temp3pm = 2132
# null count in RainToday = 617
# null count in Year = 0
# null count in Month = 0
# null count in Day = 0
# null count in 2_Location = 0
# null count in 2_MinTemp = 397
# null count in 2_MaxTemp = 260
# null count in 2_Rainfall = 0
# null count in 2_Evaporation = 51779
# null count in 2_Sunshine = 58725
# null count in 2_WindGustDir = 8244
# null count in 2_WindGustSpeed = 8219
# null count in 2_WindDir9am = 8543
# null count in 2_WindDir3pm = 3053
# null count in 2_WindSpeed9am = 881
# null count in 2_WindSpeed3pm = 2042
# null count in 2_Humidity9am = 1309
# null count in 2_Humidity3pm = 2928
# null count in 2_Pressure9am = 12084
# null count in 2_Pressure3pm = 12082
# null count in 2_Cloud9am = 45721
# null count in 2_Cloud3pm = 48663
# null count in 2_Temp9am = 516
# null count in 2_Temp3pm = 2110
# null count in 2_RainToday = 0
# null count in 2_Year = 0
# null count in 2_Month = 0
# null count in 2_Day = 0
# null count in 3_Location = 0
# null count in 3_MinTemp = 391
# null count in 3_MaxTemp = 260
# null count in 3_Rainfall = 0
# null count in 3_Evaporation = 51850
# null count in 3_Sunshine = 58745
# null count in 3_WindGustDir = 8242
# null count in 3_WindGustSpeed = 8217
# null count in 3_WindDir9am = 8540
# null count in 3_WindDir3pm = 3042
# null count in 3_WindSpeed9am = 880
# null count in 3_WindSpeed3pm = 2038
# null count in 3_Humidity9am = 1309
# null count in 3_Humidity3pm = 2921
# null count in 3_Pressure9am = 12082
# null count in 3_Pressure3pm = 12080
# null count in 3_Cloud9am = 45762
# null count in 3_Cloud3pm = 48714
# null count in 3_Temp9am = 516
# null count in 3_Temp3pm = 2105
# null count in 3_RainToday = 0
# null count in 3_Year = 0
# null count in 3_Month = 0
# null count in 3_Day = 0
# null count in 4_Location = 0
# null count in 4_MinTemp = 391
# null count in 4_MaxTemp = 261
# null count in 4_Rainfall = 0
# null count in 4_Evaporation = 51888
# null count in 4_Sunshine = 58778
# null count in 4_WindGustDir = 8240
# null count in 4_WindGustSpeed = 8215
# null count in 4_WindDir9am = 8537
# null count in 4_WindDir3pm = 3048
# null count in 4_WindSpeed9am = 877
# null count in 4_WindSpeed3pm = 2041
# null count in 4_Humidity9am = 1308
# null count in 4_Humidity3pm = 2926
# null count in 4_Pressure9am = 12079
# null count in 4_Pressure3pm = 12079
# null count in 4_Cloud9am = 45787
# null count in 4_Cloud3pm = 48741
# null count in 4_Temp9am = 514
# null count in 4_Temp3pm = 2110
# null count in 4_RainToday = 0
# null count in 4_Year = 0
# null count in 4_Month = 0
# null count in 4_Day = 0
# null count in 5_Location = 0
# null count in 5_MinTemp = 391
# null count in 5_MaxTemp = 257
# null count in 5_Rainfall = 0
# null count in 5_Evaporation = 51904
# null count in 5_Sunshine = 58792
# null count in 5_WindGustDir = 8244
# null count in 5_WindGustSpeed = 8219
# null count in 5_WindDir9am = 8549
# null count in 5_WindDir3pm = 3053
# null count in 5_WindSpeed9am = 874
# null count in 5_WindSpeed3pm = 2047
# null count in 5_Humidity9am = 1304
# null count in 5_Humidity3pm = 2929
# null count in 5_Pressure9am = 12077
# null count in 5_Pressure3pm = 12080
# null count in 5_Cloud9am = 45768
# null count in 5_Cloud3pm = 48735
# null count in 5_Temp9am = 511
# null count in 5_Temp3pm = 2114
# null count in 5_RainToday = 0
# null count in 5_Year = 0
# null count in 5_Month = 0
# null count in 5_Day = 0
# null count in 6_Location = 0
# null count in 6_MinTemp = 386
# null count in 6_MaxTemp = 256
# null count in 6_Rainfall = 0
# null count in 6_Evaporation = 51917
# null count in 6_Sunshine = 58790
# null count in 6_WindGustDir = 8243
# null count in 6_WindGustSpeed = 8218
# null count in 6_WindDir9am = 8551
# null count in 6_WindDir3pm = 3060
# null count in 6_WindSpeed9am = 872
# null count in 6_WindSpeed3pm = 2050
# null count in 6_Humidity9am = 1297
# null count in 6_Humidity3pm = 2929
# null count in 6_Pressure9am = 12078
# null count in 6_Pressure3pm = 12082
# null count in 6_Cloud9am = 45741
# null count in 6_Cloud3pm = 48740
# null count in 6_Temp9am = 506
# null count in 6_Temp3pm = 2118
# null count in 6_RainToday = 0
# null count in 6_Year = 0
# null count in 6_Month = 0
# null count in 6_Day = 0
# null count in 7_Location = 0
# null count in 7_MinTemp = 383
# null count in 7_MaxTemp = 252
# null count in 7_Rainfall = 0
# null count in 7_Evaporation = 51916
# null count in 7_Sunshine = 58778
# null count in 7_WindGustDir = 8239
# null count in 7_WindGustSpeed = 8215
# null count in 7_WindDir9am = 8557
# null count in 7_WindDir3pm = 3066
# null count in 7_WindSpeed9am = 870
# null count in 7_WindSpeed3pm = 2057
# null count in 7_Humidity9am = 1292
# null count in 7_Humidity3pm = 2935
# null count in 7_Pressure9am = 12081
# null count in 7_Pressure3pm = 12086
# null count in 7_Cloud9am = 45716
# null count in 7_Cloud3pm = 48732
# null count in 7_Temp9am = 503
# null count in 7_Temp3pm = 2127
# null count in 7_RainToday = 0
# null count in 7_Year = 0
# null count in 7_Month = 0
# null count in 7_Day = 0
# null count in rainafter1days = 0
# null count in rainafter2days = 0
# null count in rainafter3days = 0
# null count in rainafter4days = 0
# null count in rainafter5days = 0
# null count in rainafter6days = 0
# null count in rainafter7days = 0

# %%
DF = DF.dropna(subset=['RainToday'])
c = 'RainToday'
print('null count in',c,'=',DF[c].isnull().sum())
# Out:
# null count in RainToday = 0

# %%
y1 = DF[['rainafter1days']]
y2 = DF[['rainafter2days']]
y3 = DF[['rainafter3days']]
y4 = DF[['rainafter4days']]
y5 = DF[['rainafter5days']]
y6 = DF[['rainafter6days']]
y7 = DF[['rainafter7days']]
DF=DF.drop(columns = ['rainafter1days','rainafter2days','rainafter3days','rainafter4days','rainafter5days','rainafter6days','rainafter7days'])

# %%
numerical_col = [i for i in DF.columns if (DF[i].dtype=='float64' or DF[i].dtype=='int64')]
objects_col = [i for i in DF.columns if DF[i].dtype=='object']

print(numerical_col)
print(objects_col)
# Out:
# ['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine', 'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am', 'Temp3pm', 'Year', 'Month', 'Day', '2_MinTemp', '2_MaxTemp', '2_Rainfall', '2_Evaporation', '2_Sunshine', '2_WindGustSpeed', '2_WindSpeed9am', '2_WindSpeed3pm', '2_Humidity9am', '2_Humidity3pm', '2_Pressure9am', '2_Pressure3pm', '2_Cloud9am', '2_Cloud3pm', '2_Temp9am', '2_Temp3pm', '2_Year', '2_Month', '2_Day', '3_MinTemp', '3_MaxTemp', '3_Rainfall', '3_Evaporation', '3_Sunshine', '3_WindGustSpeed', '3_WindSpeed9am', '3_WindSpeed3pm', '3_Humidity9am', '3_Humidity3pm', '3_Pressure9am', '3_Pressure3pm', '3_Cloud9am', '3_Cloud3pm', '3_Temp9am', '3_Temp3pm', '3_Year', '3_Month', '3_Day', '4_MinTemp', '4_MaxTemp', '4_Rainfall', '4_Evaporation', '4_Sunshine', '4_WindGustSpeed', '4_WindSpeed9am', '4_WindSpeed3pm', '4_Humidity9am', '4_Humidity3pm', '4_Pressure9am', '4_Pressure3pm', '4_Cloud9am', '4_Cloud3pm', '4_Temp9am', '4_Temp3pm', '4_Year', '4_Month', '4_Day', '5_MinTemp', '5_MaxTemp', '5_Rainfall', '5_Evaporation', '5_Sunshine', '5_WindGustSpeed', '5_WindSpeed9am', '5_WindSpeed3pm', '5_Humidity9am', '5_Humidity3pm', '5_Pressure9am', '5_Pressure3pm', '5_Cloud9am', '5_Cloud3pm', '5_Temp9am', '5_Temp3pm', '5_Year', '5_Month', '5_Day', '6_MinTemp', '6_MaxTemp', '6_Rainfall', '6_Evaporation', '6_Sunshine', '6_WindGustSpeed', '6_WindSpeed9am', '6_WindSpeed3pm', '6_Humidity9am', '6_Humidity3pm', '6_Pressure9am', '6_Pressure3pm', '6_Cloud9am', '6_Cloud3pm', '6_Temp9am', '6_Temp3pm', '6_Year', '6_Month', '6_Day', '7_MinTemp', '7_MaxTemp', '7_Rainfall', '7_Evaporation', '7_Sunshine', '7_WindGustSpeed', '7_WindSpeed9am', '7_WindSpeed3pm', '7_Humidity9am', '7_Humidity3pm', '7_Pressure9am', '7_Pressure3pm', '7_Cloud9am', '7_Cloud3pm', '7_Temp9am', '7_Temp3pm', '7_Year', '7_Month', '7_Day']
# ['Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm', 'RainToday', '2_Location', '2_WindGustDir', '2_WindDir9am', '2_WindDir3pm', '2_RainToday', '3_Location', '3_WindGustDir', '3_WindDir9am', '3_WindDir3pm', '3_RainToday', '4_Location', '4_WindGustDir', '4_WindDir9am', '4_WindDir3pm', '4_RainToday', '5_Location', '5_WindGustDir', '5_WindDir9am', '5_WindDir3pm', '5_RainToday', '6_Location', '6_WindGustDir', '6_WindDir9am', '6_WindDir3pm', '6_RainToday', '7_Location', '7_WindGustDir', '7_WindDir9am', '7_WindDir3pm', '7_RainToday']

# %%
y=[y1,y2,y3,y4,y5,y6,y7]
for i in range(len(y)):
  y[i] = y[i].replace(to_replace={'Yes':1,'No':0})

# %%
display(DF)
# Out:
#         Location  MinTemp  MaxTemp  ...  7_Year  7_Month  7_Day
# 0       Canberra      8.0     24.3  ...    2007       11      7
# 1       Canberra     14.0     26.9  ...    2007       11      8
# 2       Canberra     13.7     23.4  ...    2007       11      9
# 3       Canberra     13.3     15.5  ...    2007       11     10
# 4       Canberra      7.6     16.1  ...    2007       11     11
# ...          ...      ...      ...  ...     ...      ...    ...
# 127428     Uluru      0.5     21.7  ...    2017        6     13
# 127429     Uluru      4.0     20.0  ...    2017        6     14
# 127430     Uluru      3.4     19.8  ...    2017        6     15
# 127431     Uluru      3.2     18.6  ...    2017        6     16
# 127432     Uluru      2.4     19.1  ...    2017        6     17
#
# [126816 rows x 168 columns]

# %%
for i in range(7):
  X_train, X_test, y_train, y_test = train_test_split(DF, y[i], test_size=0.2, stratify=y[i], random_state=0)
  t = X_train.median()
  X_train = X_train.fillna(t)
  X_test = X_test.fillna(t)

  for t_df in [X_train, X_test]:
    t_df['WindGustDir'].fillna(X_train['WindGustDir'].mode()[0], inplace=True)
    t_df['WindDir9am'].fillna(X_train['WindDir9am'].mode()[0], inplace=True)
    t_df['WindDir3pm'].fillna(X_train['WindDir3pm'].mode()[0], inplace=True)
    t_df['RainToday'].fillna(X_train['RainToday'].mode()[0], inplace=True)

  X_train = pd.concat([X_train[numerical_col], pd.get_dummies(X_train.Location,prefix='Location'),
                      pd.get_dummies(X_train.WindGustDir,prefix='WindGustDir'),
                      pd.get_dummies(X_train.WindDir9am,prefix='WindDir9am'),
                      pd.get_dummies(X_train.WindDir3pm,prefix='WindDir3pm'),
                      pd.get_dummies(X_train.RainToday,prefix='RainToday')], axis=1)

  X_test = pd.concat([X_test[numerical_col], pd.get_dummies(X_test.Location,prefix='Location'),
                      pd.get_dummies(X_test.WindGustDir,prefix='WindGustDir'),
                      pd.get_dummies(X_test.WindDir9am,prefix='WindDir9am'),
                      pd.get_dummies(X_test.WindDir3pm,prefix='WindDir3pm'),
                      pd.get_dummies(X_test.RainToday,prefix='RainToday')], axis=1)
  scaler = MinMaxScaler()
  X_train = scaler.fit_transform(X_train)
  X_test = scaler.transform(X_test) 
  clf = RandomForestClassifier(n_estimators=200, random_state=0)
  clf.fit(X_train, y_train)
  y_pred_test = clf.predict_proba(X_test)
  
  y_pred=np.zeros(len(y_pred_test))
  for j in range(len(y_pred_test)):
    if y_pred_test[j][1]>=0.38-i*0.01:
      y_pred[j]=1
  
  print('Day '+str(i+1),'Model test accuracy score : {0:0.4f}'. format(accuracy_score(y_test, y_pred)))
  print('Model train accuracy score : {0:0.4f}'. format(accuracy_score(y_train, y_pred_train)))
  
  cm = confusion_matrix(y_test, y_pred)
  cm_matrix = pd.DataFrame(data=cm, columns=['Predict Negative:0', 'Predict Positive:1'], 
                                 index=['Actual Negative:0', 'Actual positive:1'])
  display(cm_matrix)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:28: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# Day 1 Model test accuracy score : 0.8561
#                    Predict Negative:0  Predict Positive:1
# Actual Negative:0               18089                1663
# Actual positive:1                1987                3625
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:28: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# Day 2 Model test accuracy score : 0.8049
#                    Predict Negative:0  Predict Positive:1
# Actual Negative:0               18181                1574
# Actual positive:1                3375                2234
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:28: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# Day 3 Model test accuracy score : 0.8031
#                    Predict Negative:0  Predict Positive:1
# Actual Negative:0               18399                1357
# Actual positive:1                3637                1971
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:28: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# Day 4 Model test accuracy score : 0.7940
#                    Predict Negative:0  Predict Positive:1
# Actual Negative:0               18101                1652
# Actual positive:1                3574                2037
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:28: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# Day 5 Model test accuracy score : 0.7951
#                    Predict Negative:0  Predict Positive:1
# Actual Negative:0               17985                1762
# Actual positive:1                3435                2182
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:28: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# Day 6 Model test accuracy score : 0.7843
#                    Predict Negative:0  Predict Positive:1
# Actual Negative:0               17547                2196
# Actual positive:1                3276                2345
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:28: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# Day 7 Model test accuracy score : 0.7782
#                    Predict Negative:0  Predict Positive:1
# Actual Negative:0               17203                2535
# Actual positive:1                3092                2534

# %%
#null accuracy
v_c=y_test.value_counts()
v_c
# Out:
# rainafter7days
# 0                 19738
# 1                  5626
# dtype: int64

# %%
null_accuracy = v_c[0]/sum(v_c)

print(null_accuracy)
# Out:
# rainafter7days
# 0                 0.77819
# dtype: float64
